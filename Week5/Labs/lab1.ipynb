# %%
import pandas as pd
import numpy as np

# Convert xls to CSV
df = pd.read_excel("Unemployment.xls")
df.to_csv("Unemployment.csv", index=False)

# %%
df = pd.read_csv("Unemployment.csv",skiprows=4)
print(f"Rows: {df.index.size} | cols: {df.columns.size} | third col: {df.columns[2]}")
df
# Out:
# Rows: 3275 | cols: 88 | third col: area_name
#       fips_txt Stabr                area_name  \
# 0            0    US            United States
# 1         1000    AL                  Alabama
# 2         1001    AL       Autauga County, AL
# 3         1003    AL       Baldwin County, AL
# 4         1005    AL       Barbour County, AL
# ...        ...   ...                      ...
# 3270     72145    PR  Vega Baja Municipio, PR
# 3271     72147    PR    Vieques Municipio, PR
# 3272     72149    PR   Villalba Municipio, PR
# 3273     72151    PR    Yabucoa Municipio, PR
# 3274     72153    PR      Yauco Municipio, PR
#
#       Rural_urban_continuum_code_2013  Urban_influence_code_2013  Metro_2013  \
# 0                                 NaN                        NaN         NaN
# 1                                 NaN                        NaN         NaN
# 2                                 2.0                        2.0         1.0
# ...

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/grbruns/cst383/master/unemployment.csv")
print(f"Rows: {df2.index.size} | cols: {df2.columns.size} | third col: {df2.columns[2]}")
df2
# Out:
# Rows: 3274 | cols: 45 | third col: Area_name
#       FIPStxt State                Area_name Rural_urban_continuum_code_2003  \
# 0        1000    AL                  Alabama
# 1        1001    AL       Autauga County, AL                               2
# 2        1003    AL       Baldwin County, AL                               4
# 3        1005    AL       Barbour County, AL                               6
# 4        1007    AL          Bibb County, AL                               1
# ...       ...   ...                      ...                             ...
# 3269    72145    PR  Vega Baja Municipio, PR                               1
# 3270    72147    PR    Vieques Municipio, PR                               7
# 3271    72149    PR   Villalba Municipio, PR                               2
# 3272    72151    PR    Yabucoa Municipio, PR                               1
# 3273    72153    PR      Yauco Municipio, PR                               3
#
# ...

# %% [markdown]
# 7. How does the work you’re doing with this data to get it into pandas data frame relate to the need to have your results be replicable?  How would you document the source of the data set, and what you did to get it into a format that Python can use?
#
#     Because the data is stored online, it easy for me to be able to pull the data. It is important to be able to replicate data because if any one wanted to verify my results or see if updated data changes the results, they would be able to. I think the best way to document my source would be to use the full URL of where I pulled the data. Also, by using my python code to process my data one, could easily see how I obtained my dataset. For example above, I input the data as an excel file, and using pandas I was able to convert the `.xls` file into a more usable `.csv` file.

# %% [markdown]
# 8. Data sets often come with associated data dictionaries that explain where the data comes from, what the attributes mean, etc.  Where is the documentation for this data set?
#
#     This set does not appear to have one. I looked at the link provided aswell as Dr. Bruns' github repo.
